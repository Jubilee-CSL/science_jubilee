# %% [markdown]
# # 3D Reconstruction with gaussian Splatting --Step by Step

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append("../../")
sys.path.append("../")
sys.path.append("../../../")
sys.path.append("../../../../")

from science_jubilee.machine_session import MachineSession
from science_jubilee.Vision.3D_Reconstruction.ingredients.colmap import run_colmap
from science_jubilee.Vision.3D_Reconstruction.ingredients.pre_process import run_colmap


def show(img, title=""):
    plt.figure(figsize=(8, 6))
    plt.imshow(img)
    plt.title(title)
    plt.axis("off")
    plt.show()

hardware=False
# Out:
#   Cell In[2], line 11
#     from science_jubilee.Vision.3D_Reconstruction.ingredients.colmap import run_colmap
#                                 ^
# SyntaxError: invalid decimal literal
